# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
from pathlib import Path

# %%
inputdir = Path("/Users/delnatan/Work/BurgessLab/imaging/Bri/wild-type/processed/processed/")
flist = list(inputdir.glob("[!.]*.tif[f]"))
for fn in flist:
    print(fn.name)
# Out:
# 2026-08-05_2026-08-05_BW_WT_T2_RnaseVSnoRnase_White Light - Brightfield_EPI - 405_F1.tiff
# 2026-08-05_2026-08-05_BW_WT_T2_RnaseVSnoRnase_White Light - Brightfield_EPI - 405_F0.tiff

# %%
img = tifffile.imread(flist[0])

# %%
from cellpose import denoise
